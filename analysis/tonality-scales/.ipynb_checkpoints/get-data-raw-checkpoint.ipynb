# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.core.debugger import set_trace
import json
from matplotlib import colors
from ast import literal_eval

# %% [markdown]
# # Load data

# %%
# psynet 11
fname = "sing-scales-v1"

PATH = f"data/{fname}/"
nodes = pd.read_csv(PATH + "CustomNode.csv", low_memory=False)
# networks = pd.read_csv(PATH + "CustomNetwork.csv", low_memory=False) # old psynet
trials = pd.read_csv(PATH + "CustomTrial.csv", low_memory=False)

# %%
print(nodes)
# Out:
#      vars    id        creation_time  failed  failed_reason  time_of_death  \
# 0      {}    17  2024-09-02 13:58:47   False            NaN            NaN
# 1      {}    18  2024-09-02 13:58:47   False            NaN            NaN
# 2      {}    19  2024-09-02 13:58:47   False            NaN            NaN
# 3      {}    20  2024-09-02 13:58:47   False            NaN            NaN
# 4      {}    21  2024-09-02 13:58:47   False            NaN            NaN
# ...   ...   ...                  ...     ...            ...            ...
# 1095   {}  1365  2024-09-02 17:10:32   False            NaN            NaN
# 1096   {}  1370  2024-09-02 17:17:22   False            NaN            NaN
# 1097   {}  1371  2024-09-02 17:17:36   False            NaN            NaN
# 1098   {}  1374  2024-09-02 17:17:52   False            NaN            NaN
# 1099   {}  1380  2024-09-02 17:18:58   False            NaN            NaN
#
#              type  network_id  participant_id   trial_maker_id  ... parent_id  \
# 0     TrialSource          17             NaN  imitation_chain  ...       NaN
# 1     TrialSource          18             NaN  imitation_chain  ...       NaN
# 2     TrialSource          19             NaN  imitation_chain  ...       NaN
# 3     TrialSource          20             NaN  imitation_chain  ...       NaN
# 4     TrialSource          21             NaN  imitation_chain  ...       NaN
# ...           ...         ...             ...              ...  ...       ...
# 1095   CustomNode          24             NaN  imitation_chain  ...    1359.0
# 1096   CustomNode          31             NaN  imitation_chain  ...    1352.0
# 1097   CustomNode          78             NaN  imitation_chain  ...    1330.0
# 1098   CustomNode          67             NaN  imitation_chain  ...    1355.0
# 1099   CustomNode         116             NaN  imitation_chain  ...    1348.0
#
#                                                    seed  \
# 0     {"register": "high", "reference_pitch": 62.636...
# 1     {"register": "high", "reference_pitch": 59.417...
# 2     {"register": "high", "reference_pitch": 63.131...
# 3     {"register": "high", "reference_pitch": 60.635...
# 4     {"register": "high", "reference_pitch": 62.030...
# ...                                                 ...
# 1095  {"num_target_pitches": 5, "target_pitches": [4...
# 1096  {"num_target_pitches": 5, "target_pitches": [4...
# 1097  {"num_target_pitches": 5, "target_pitches": [4...
# 1098  {"num_target_pitches": 5, "target_pitches": [4...
# 1099  {"num_target_pitches": 5, "target_pitches": [4...
#
#                                              definition  context  \
# 0     {"register": "high", "reference_pitch": 62.636...      NaN
# 1     {"register": "high", "reference_pitch": 59.417...      NaN
# 2     {"register": "high", "reference_pitch": 63.131...      NaN
# 3     {"register": "high", "reference_pitch": 60.635...      NaN
# 4     {"register": "high", "reference_pitch": 62.030...      NaN
# ...                                                 ...      ...
# 1095  {"num_target_pitches": 5, "target_pitches": [4...      NaN
# 1096  {"num_target_pitches": 5, "target_pitches": [4...      NaN
# 1097  {"num_target_pitches": 5, "target_pitches": [4...      NaN
# 1098  {"num_target_pitches": 5, "target_pitches": [4...      NaN
# 1099  {"num_target_pitches": 5, "target_pitches": [4...      NaN
#
#       participant_group    block  propagate_failure  n_viable_trials  \
# 0               default  default              False                1
# 1               default  default              False                1
# 2               default  default              False                1
# 3               default  default              False                1
# 4               default  default              False                1
# ...                 ...      ...                ...              ...
# 1095            default  default               True                0
# 1096            default  default               True                0
# 1097            default  default               True                0
# 1098            default  default               True                0
# 1099            default  default               True                0
#
#            class  object_type
# 0     CustomNode         Node
# 1     CustomNode         Node
# 2     CustomNode         Node
# 3     CustomNode         Node
# 4     CustomNode         Node
# ...          ...          ...
# 1095  CustomNode         Node
# 1096  CustomNode         Node
# 1097  CustomNode         Node
# 1098  CustomNode         Node
# 1099  CustomNode         Node
#
# [1100 rows x 32 columns]

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])
node_data["definition"].iloc[1]

def find_end_tt(d, end_tt_list=None):
    if end_tt_list is None:
        end_tt_list = []
    if isinstance(d, dict):
        for key, value in d.items():
            if key == "start_tt":
                end_tt_list.append(value)
            elif isinstance(value, (dict, list)):
                find_end_tt(value, end_tt_list)
    elif isinstance(d, list):
        for item in d:
            find_end_tt(item, end_tt_list)
    return end_tt_list


node_data['start_tt'] = node_data['definition'].apply(lambda x: find_end_tt(json.loads(x)))

print(node_data['start_tt'])
# Out:
# 0                                                      []
# 148     [1062.3809523809523, 1799.3650793650793, 2676....
# 310     [1967.687074829932, 2835.3968253968255, 3937.0...
# 386     [1560.6802721088436, 1940.8616780045352, 2911....
# 599     [1169.7732426303855, 1744.6258503401361, 2773....
#                               ...
# 708     [1147.2562358276643, 1884.7845804988663, 2553....
# 852     [1442.9478458049887, 2099.0022675736964, 2721....
# 1073    [1232.5170068027212, 2001.5419501133788, 2682....
# 1082    [1497.6417233560092, 2097.1428571428573, 2777....
# 1099    [1268.2086167800453, 1902.2222222222222, 2583....
# Name: start_tt, Length: 1100, dtype: object

# %% [markdown]
# # Preprocess data

# %%
# filter nodes
node_data = nodes
node_data = node_data[node_data["failed"] == False]
node_data = node_data[["id", "network_id", "degree", "trial_maker_id", "definition", "seed"]]
node_data = node_data.sort_values(["network_id", "degree"])

# process node definition
mel_id = []
# register = []
trial_type = []
target_pitches = []
# reference_pitch = []
target_intervals = []
target_note_durations = []
# target_ISIs = []

for i in range(len(node_data)):
    print()
    # definition = node_data["definition"].to_numpy()[i]
    # definition = literal_eval(definition)
    # definition = [d["content"] for d in definition if d["is_center"]][0]

    definition_str = node_data["definition"].iloc[i]  # Access the string directly
    print(definition_str)
    definition = json.loads(definition_str)  # Parse JSON string into dictionary
    # definition = [d["content"] for d in definition if d["is_center"]][0]
    
    # mel_id.append(definition["mel_id"])
    # register.append(definition["register"])
    trial_type.append(definition["trial_type"])
    target_pitches.append(definition["target_pitches"])
    # reference_pitch.append(definition["reference_pitch"])
    target_intervals.append(definition["target_intervals"])
    target_note_durations.append(definition["target_note_durations"])
    # target_ISIs.append(definition["target_ISIs"])

# node_data["mel_id"] = mel_id
# node_data["register"] = register
node_data["trial_type"] = trial_type
node_data["target_pitches"] = target_pitches
# node_data["reference_pitch"] = reference_pitch
node_data["target_intervals"] = target_intervals
node_data["target_note_durations"] = target_note_durations
# node_data["target_ISIs"] = target_ISIs
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
node_data
# Out:
#         id  network_id  degree   trial_maker_id  \
# 0       17          17       0  imitation_chain
# 148    183          17       1  imitation_chain
# 310    406          17       2  imitation_chain
# 386    485          17       3  imitation_chain
# 599    751          17       4  imitation_chain
# ...    ...         ...     ...              ...
# 708    882         116       6  imitation_chain
# 852   1063         116       7  imitation_chain
# 1073  1338         116       8  imitation_chain
# 1082  1348         116       9  imitation_chain
# 1099  1380         116      10  imitation_chain
#
#                                              definition  \
# 0     {"register": "high", "reference_pitch": 62.636...
# 148   {"num_target_pitches": 5, "target_pitches": [6...
# 310   {"num_target_pitches": 5, "target_pitches": [5...
# 386   {"num_target_pitches": 5, "target_pitches": [6...
# 599   {"num_target_pitches": 5, "target_pitches": [5...
# ...                                                 ...
# 708   {"num_target_pitches": 5, "target_pitches": [5...
# 852   {"num_target_pitches": 5, "target_pitches": [4...
# 1073  {"num_target_pitches": 5, "target_pitches": [5...
# 1082  {"num_target_pitches": 5, "target_pitches": [4...
# 1099  {"num_target_pitches": 5, "target_pitches": [4...
#
#                                                    seed    trial_type  \
# 0     {"register": "high", "reference_pitch": 62.636...  source_trial
# 148   {"num_target_pitches": 5, "target_pitches": [6...    node_trial
# 310   {"num_target_pitches": 5, "target_pitches": [5...    node_trial
# 386   {"num_target_pitches": 5, "target_pitches": [6...    node_trial
# 599   {"num_target_pitches": 5, "target_pitches": [5...    node_trial
# ...                                                 ...           ...
# 708   {"num_target_pitches": 5, "target_pitches": [5...    node_trial
# 852   {"num_target_pitches": 5, "target_pitches": [4...    node_trial
# 1073  {"num_target_pitches": 5, "target_pitches": [5...    node_trial
# 1082  {"num_target_pitches": 5, "target_pitches": [4...    node_trial
# 1099  {"num_target_pitches": 5, "target_pitches": [4...    node_trial
#
#                                          target_pitches  \
# 0     [66.29423328221986, 68.37345953045224, 58.3050...
# 148   [66.45552026998996, 68.42614993628999, 60.5072...
# 310   [57.22227403476229, 47.78410325266855, 47.0175...
# 386   [60.56054168093128, 64.49878625266268, 54.4193...
# 599   [51.42588683575288, 61.20576434207672, 47.9626...
# ...                                                 ...
# 708   [54.72336295699853, 60.24740690287071, 65.6901...
# 852   [40.55817925930616, 46.03857459119243, 50.2608...
# 1073  [55.24771562119287, 57.643386991572186, 59.200...
# 1082  [44.185749360354166, 46.20529608743849, 47.895...
# 1099  [42.00471354667708, 44.938992788371415, 46.663...
#
#                                        target_intervals  \
# 0     [2.0792262482323736, -10.06836170739124, -0.53...
# 148   [1.9706296663000273, -7.918929248557561, -4.31...
# 310   [-9.438170782093742, -0.7665657876710483, -1.5...
# 386   [3.9382445717314027, -10.079460891374232, -0.0...
# 599   [9.779877506323842, -13.243082940262894, 4.556...
# ...                                                 ...
# 708   [5.5240439458721795, 5.4427856024913694, -7.64...
# 852   [5.480395331886271, 4.222249923425409, -9.4663...
# 1073  [2.3956713703793184, 1.5569759068023217, -4.73...
# 1082  [2.0195467270843253, 1.6897888146100186, -4.90...
# 1099  [2.934279241694334, 1.7249570215552197, -4.640...
#
#                                   target_note_durations
# 0     [0.6654622319045722, 0.7846330520069773, 1.270...
# 148   [0.5828344671201815, 0.6868934240362812, 1.052...
# 310   [0.6679365079365079, 0.6052380952380949, 0.598...
# 386   [0.3172335600907029, 0.7334013605442176, 0.764...
# 599   [0.37065759637188195, 0.5934013605442175, 0.56...
# ...                                                 ...
# 708   [0.6495238095238096, 0.5936507936507935, 0.721...
# 852   [0.45551020408163256, 0.4367573696145123, 0.53...
# 1073  [0.5416099773242629, 0.4888888888888887, 0.455...
# 1082  [0.469705215419501, 0.528956916099773, 0.75038...
# 1099  [0.4579591836734694, 0.5876190476190477, 0.634...
#
# [1100 rows x 10 columns]

# %% [markdown]
# # Export node data to csv

# %%
node_data.to_csv(f"{fname}_node_data.csv")

# %% [markdown]
# # Trial level data

# %%
# filter trials
trial_data = trials
trial_data = trial_data[trial_data["failed"] == False]

degrees = []

for i in range(len(trial_data)):
    current_node_id = trial_data.iloc[i]["origin_id"]
    current_nodes = node_data[node_data["id"] == current_node_id]
    current_degree = current_nodes["degree"].to_numpy()[0]
    # answer = d['listen_and_rate_trial_seed']['valence']
    # current_vertex_id = current_nodes["vertex_id"].to_numpy()[0]
    # current_dependent_vertex_ids = current_nodes["dependent_vertex_ids"].to_numpy()[0]
    degrees.append(current_degree)
    # vertex_ids.append(current_vertex_id)
    # dependent_vertex_ids.append(current_dependent_vertex_ids)

trial_data["degree"] = degrees

trial_data = trial_data[["id", "network_id", "degree", "trial_maker_id", "origin_id", "participant_id", "analysis"]]
trial_data = trial_data.sort_values(["network_id", "degree"])
# Out:
# /var/folders/v7/s8wj18ld78gdbf0vgx1ptf7r0000gr/T/ipykernel_30846/4239617211.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trial_data["degree"] = degrees

# %%
trial_data
# Out:
#         id  network_id  degree   trial_maker_id  origin_id  participant_id  \
# 61     150          17       0  imitation_chain         17               4
# 268    633          17       1  imitation_chain        183              37
# 351    724          17       2  imitation_chain        406              29
# 596   1244          17       3  imitation_chain        485              65
# 750   1480          17       4  imitation_chain        751              69
# ...    ...         ...     ...              ...        ...             ...
# 735   1464         116       5  imitation_chain        606              71
# 906   1779         116       6  imitation_chain        882              81
# 1166  2278         116       7  imitation_chain       1063             110
# 1177  2296         116       8  imitation_chain       1338             111
# 1202  2375         116       9  imitation_chain       1348             116
#
#                                                analysis
# 61    {"failed": false, "reason": "All good", "regis...
# 268   {"failed": false, "reason": "All good", "regis...
# 351   {"failed": false, "reason": "All good", "regis...
# 596   {"failed": false, "reason": "All good", "regis...
# 750   {"failed": false, "reason": "All good", "regis...
# ...                                                 ...
# 735   {"failed": false, "reason": "All good", "regis...
# 906   {"failed": false, "reason": "All good", "regis...
# 1166  {"failed": false, "reason": "All good", "regis...
# 1177  {"failed": false, "reason": "All good", "regis...
# 1202  {"failed": false, "reason": "All good", "regis...
#
# [1000 rows x 7 columns]

# %% [markdown]
# # Export trial data to csv

# %%
trial_data.to_csv(f"{fname}_trial_data.csv")

# %% [markdown]
# # Experiment Cost and Demographics

# %%
participants = pd.read_csv(PATH + "participant.csv", low_memory=False)

# %%
valid_participants = participants[participants["complete"] == True]
valid_participants = valid_participants[valid_participants["failed"] == False]
experiment_summary = {
    "N_participants": valid_participants.shape[0],
    "cost": participants["base_pay"].sum() + participants["bonus"].sum()
}

experiment_summary
# Out:
# {'N_participants': 77, 'cost': 247.8}
